# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
root3 = 1.73205080757

# CSVファイルを読み込む
df = pd.read_csv('out.csv')
# df2 = pd.read_csv('out2.csv')



# データをプロットする
plt.plot(df['x'],df['y'],label="newton_method")
# plt.plot(df2['x'],df2['y'],label="root3",linestyle='--')


# グラフを表示する
plt.legend()
plt.show()
